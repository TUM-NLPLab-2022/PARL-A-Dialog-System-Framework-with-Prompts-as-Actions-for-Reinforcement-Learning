# %% [markdown]
# this notebook was originally created by Tao; I blended the inference into it and made some modification.

# %%
# !pip install transformers datasets

# %%
from datasets import load_dataset

dataset = load_dataset("Adapting/empathetic_dialogues_with_special_tokens")
# Out:
# Using custom data configuration Adapting--empathetic_dialogues_with_special_tokens-0f2d82ee5e7ce8f0
# Reusing dataset csv (/root/.cache/huggingface/datasets/Adapting___csv/Adapting--empathetic_dialogues_with_special_tokens-0f2d82ee5e7ce8f0/0.0.0/652c3096f041ee27b04d2232d41f10547a8fecda3e284a79a0ec4053c916ef7a)
#   0%|          | 0/3 [00:00<?, ?it/s]

# %%
test_dataset = dataset['test']

# %%
test_dataset
# Out:
# Dataset({
#     features: ['Unnamed: 0', 'id', 'chat_history', 'sys_response', 'situation', 'emotion', 'question or not', 'behavior'],
#     num_rows: 5255
# })

# %%
import pandas as pd

# %%
test_dataset = test_dataset.to_pandas()

# %%
test_dataset
# Out:
#       Unnamed: 0    id                                       chat_history  \
# 0              0     0  [usr] Yeah about 10 years ago I had a horrifyi...
# 1              1     1  [usr] Yeah about 10 years ago I had a horrifyi...
# 2              2     2  [usr] Well, can you tell me about your experie...
# 3              3     3  [usr] Well, can you tell me about your experie...
# 4              4     4  [usr] I there, dont know what to do, jst broke...
# ...          ...   ...                                                ...
# 5250        5250  5250  [usr] My friend showed me his Minecraft world ...
# 5251        5251  5251  [usr] I had to cancel our family vacation comi...
# 5252        5252  5252  [usr] I had to cancel our family vacation comi...
# 5253        5253  5253  [usr] Life is good, it's the gift that keeps o...
# 5254        5254  5254  [usr] Life is good, it's the gift that keeps o...
#
#                                            sys_response  \
# 0                          Did you suffer any injuries?
# 1     Why did you feel guilty? People really shouldn...
# 2     Yeah i wanted to tell you about the time i was...
# 3                Yeah he was punished hes in jail still
# 4     sorry to hear! do you have any idea about the ...
# ...                                                 ...
# 5250  That's super cool, I played a few years back b...
# 5251  I am really sorry to hear that.  I hope everyt...
# 5252  Well, that is just terrible.  I hate it when c...
# 5253                  that is a great way to look at it
# 5254   Yeah more people should look at life like you do
#
#                                               situation       emotion  \
# 0     I felt guilty when I was driving home one nigh...        guilty
# 1     I felt guilty when I was driving home one nigh...        guilty
# 2     My mother stopped by my house one day and said...        caring
# 3     My mother stopped by my house one day and said...        caring
# 4     I just broke up with my girlfriend, we were to...        lonely
# ...                                                 ...           ...
# 5250  I was totally surprised when I saw my friend's...     impressed
# 5251  Had to cancel our family vacation coming up ne...  disappointed
# 5252  Had to cancel our family vacation coming up ne...  disappointed
# 5253             I'm glad that life is being good to me      grateful
# 5254             I'm glad that life is being good to me      grateful
#
#                  question or not  \
# 0     ask me for further details
# 1     ask me for further details
# 2                         [None]
# 3                         [None]
# 4     ask me for further details
# ...                          ...
# 5250                      [None]
# 5251                      [None]
# 5252                      [None]
# 5253                      [None]
# 5254                      [None]
#
#                                                behavior
# 0                                                [None]
# 1            I'm in a negative mood, please comfort me.
# 2                                                [None]
# 3                                                [None]
# 4            I'm in a negative mood, please comfort me.
# ...                                                 ...
# 5250  I'm in a positive mood, please congratulate me...
# 5251         I'm in a negative mood, please comfort me.
# 5252         I'm in a negative mood, please comfort me.
# 5253                                             [None]
# 5254                                             [None]
#
# [5255 rows x 8 columns]

# %%
test_dataset['RLPA_response'] = 0

# %%
test_dataset
# Out:
#       Unnamed: 0    id                                       chat_history  \
# 0              0     0  [usr] Yeah about 10 years ago I had a horrifyi...
# 1              1     1  [usr] Yeah about 10 years ago I had a horrifyi...
# 2              2     2  [usr] Well, can you tell me about your experie...
# 3              3     3  [usr] Well, can you tell me about your experie...
# 4              4     4  [usr] I there, dont know what to do, jst broke...
# ...          ...   ...                                                ...
# 5250        5250  5250  [usr] My friend showed me his Minecraft world ...
# 5251        5251  5251  [usr] I had to cancel our family vacation comi...
# 5252        5252  5252  [usr] I had to cancel our family vacation comi...
# 5253        5253  5253  [usr] Life is good, it's the gift that keeps o...
# 5254        5254  5254  [usr] Life is good, it's the gift that keeps o...
#
#                                            sys_response  \
# 0                          Did you suffer any injuries?
# 1     Why did you feel guilty? People really shouldn...
# 2     Yeah i wanted to tell you about the time i was...
# 3                Yeah he was punished hes in jail still
# 4     sorry to hear! do you have any idea about the ...
# ...                                                 ...
# 5250  That's super cool, I played a few years back b...
# 5251  I am really sorry to hear that.  I hope everyt...
# 5252  Well, that is just terrible.  I hate it when c...
# 5253                  that is a great way to look at it
# 5254   Yeah more people should look at life like you do
#
#                                               situation       emotion  \
# 0     I felt guilty when I was driving home one nigh...        guilty
# 1     I felt guilty when I was driving home one nigh...        guilty
# 2     My mother stopped by my house one day and said...        caring
# 3     My mother stopped by my house one day and said...        caring
# 4     I just broke up with my girlfriend, we were to...        lonely
# ...                                                 ...           ...
# 5250  I was totally surprised when I saw my friend's...     impressed
# 5251  Had to cancel our family vacation coming up ne...  disappointed
# 5252  Had to cancel our family vacation coming up ne...  disappointed
# 5253             I'm glad that life is being good to me      grateful
# 5254             I'm glad that life is being good to me      grateful
#
#                  question or not  \
# 0     ask me for further details
# 1     ask me for further details
# 2                         [None]
# 3                         [None]
# 4     ask me for further details
# ...                          ...
# 5250                      [None]
# 5251                      [None]
# 5252                      [None]
# 5253                      [None]
# 5254                      [None]
#
#                                                behavior  RLPA_response
# 0                                                [None]              0
# 1            I'm in a negative mood, please comfort me.              0
# 2                                                [None]              0
# 3                                                [None]              0
# 4            I'm in a negative mood, please comfort me.              0
# ...                                                 ...            ...
# 5250  I'm in a positive mood, please congratulate me...              0
# 5251         I'm in a negative mood, please comfort me.              0
# 5252         I'm in a negative mood, please comfort me.              0
# 5253                                             [None]              0
# 5254                                             [None]              0
#
# [5255 rows x 9 columns]

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import os
os.chdir("/content/drive/MyDrive/NLP/dialog-generation-with-a-dynamic-human-preference-predictor")

# %%
# !pip install -r requirements.txt  --no-dependencies
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting en-core-web-sm@ https://github.com/explosion/spacy-models/releases/download/en_core_web_sm-3.4.0/en_core_web_sm-3.4.0-py3-none-any.whl
#   Downloading https://github.com/explosion/spacy-models/releases/download/en_core_web_sm-3.4.0/en_core_web_sm-3.4.0-py3-none-any.whl (12.8 MB)
#      |████████████████████████████████| 12.8 MB 8.2 MB/s
# Collecting jaxlib@ https://storage.googleapis.com/jax-releases/cuda11/jaxlib-0.3.14+cuda11.cudnn805-cp37-none-manylinux2014_x86_64.whl
#   Using cached https://storage.googleapis.com/jax-releases/cuda11/jaxlib-0.3.14+cuda11.cudnn805-cp37-none-manylinux2014_x86_64.whl (249.8 MB)
# Requirement already satisfied: absl-py==1.2.0 in /usr/local/lib/python3.7/dist-packages (from -r requirements.txt (line 1)) (1.2.0)
# Requirement already satisfied: aiohttp==3.8.1 in /usr/local/lib/python3.7/dist-packages (from -r requirements.txt (line 2)) (3.8.1)
# Requirement already satisfied: aiosignal==1.2.0 in /usr/local/lib/python3.7/dist-packages (from -r requirements.txt (line 3)) (1.2.0)
# Requirement already satisfied: alabaster==0.7.12 in /usr/local/lib/python3.7/dist-packages (from -r requirements.txt (line 4)) (0.7.12)
# Requirement already satisfied: albumentations==1.2.1 in /usr/local/lib/python3.7/dist-packages (from -r requirements.txt (line 5)) (1.2.1)
# Requirement already satisfied: altair==4.2.0 in /usr/local/lib/python3.7/dist-packages (from -r requirements.txt (line 6)) (4.2.0)
# Requirement already satisfied: appdirs==1.4.4 in /usr/local/lib/python3.7/dist-packages (from -r requirements.txt (line 7)) (1.4.4)
# Requirement already satisfied: argon2-cffi==21.3.0 in /usr/local/lib/python3.7/dist-packages (from -r requirements.txt (line 8)) (21.3.0)
# Requirement already satisfied: argon2-cffi-bindings==21.2.0 in /usr/local/lib/python3.7/dist-packages (from -r requirements.txt (line 9)) (21.2.0)
# Requirement already satisfied: arviz==0.12.1 in /usr/local/lib/python3.7/dist-packages (from -r requirements.txt (line 10)) (0.12.1)
# Requirement already satisfied: astor==0.8.1 in /usr/local/lib/python3.7/dist-packages (from -r requirements.txt (line 11)) (0.8.1)
# Requirement already satisfied: astropy==4.3.1 in /usr/local/lib/python3.7/dist-packages (from -r requirements.txt (line 12)) (4.3.1)
# Requirement already satisfied: astunparse==1.6.3 in /usr/local/lib/python3.7/dist-packages (from -r requirements.txt (line 13)) (1.6.3)
# Requirement already satisfied: async-timeout==4.0.2 in /usr/local/lib/python3.7/dist-packages (from -r requirements.txt (line 14)) (4.0.2)
# Requirement already satisfied: asynctest==0.13.0 in /usr/local/lib/python3.7/dist-packages (from -r requirements.txt (line 15)) (0.13.0)
# Requirement already satisfied: atari-py==0.2.9 in /usr/local/lib/python3.7/dist-packages (from -r requirements.txt (line 16)) (0.2.9)
# Requirement already satisfied: atomicwrites==1.4.1 in /usr/local/lib/python3.7/dist-packages (from -r requirements.txt (line 17)) (1.4.1)
# Requirement already satisfied: attrs==22.1.0 in /usr/local/lib/python3.7/dist-packages (from -r requirements.txt (line 18)) (22.1.0)
# Requirement already satisfied: audioread==2.1.9 in /usr/local/lib/python3.7/dist-packages (from -r requirements.txt (line 19)) (2.1.9)
# Requirement already satisfied: autograd==1.4 in /usr/local/lib/python3.7/dist-packages (from -r requirements.txt (line 20)) (1.4)
# Requirement already satisfied: Babel==2.10.3 in /usr/local/lib/python3.7/dist-packages (from -r requirements.txt (line 21)) (2.10.3)
# Requirement already satisfied: backcall==0.2.0 in /usr/local/lib/python3.7/dist-packages (from -r requirements.txt (line 22)) (0.2.0)
# Requirement already satisfied: beautifulsoup4==4.6.3 in /usr/local/lib/python3.7/dist-packages (from -r requirements.txt (line 23)) (4.6.3)
# Requirement already satisfied: bleach==5.0.1 in /usr/local/lib/python3.7/dist-packages (from -r requirements.txt (line 24)) (5.0.1)
# Requirement already satisfied: blis==0.7.8 in /usr/local/lib/python3.7/dist-packages (from -r requirements.txt (line 25)) (0.7.8)
# Requirement already satisfied: bokeh==2.3.3 in /usr/local/lib/python3.7/dist-packages (from -r requirements.txt (line 26)) (2.3.3)
# Requirement already satisfied: branca==0.5.0 in /usr/local/lib/python3.7/dist-packages (from -r requirements.txt (line 27)) (0.5.0)
# Requirement already satisfied: bs4==0.0.1 in /usr/local/lib/python3.7/dist-packages (from -r requirements.txt (line 28)) (0.0.1)
# Requirement already satisfied: CacheControl==0.12.11 in /usr/local/lib/python3.7/dist-packages (from -r requirements.txt (line 29)) (0.12.11)
# Requirement already satisfied: cached-property==1.5.2 in /usr/local/lib/python3.7/dist-packages (from -r requirements.txt (line 30)) (1.5.2)
# Requirement already satisfied: cachetools==4.2.4 in /usr/local/lib/python3.7/dist-packages (from -r requirements.txt (line 31)) (4.2.4)
# Requirement already satisfied: catalogue==2.0.8 in /usr/local/lib/python3.7/dist-packages (from -r requirements.txt (line 32)) (2.0.8)
# Requirement already satisfied: certifi==2022.6.15 in /usr/local/lib/python3.7/dist-packages (from -r requirements.txt (line 33)) (2022.6.15)
# Requirement already satisfied: cffi==1.15.1 in /usr/local/lib/python3.7/dist-packages (from -r requirements.txt (line 34)) (1.15.1)
# Requirement already satisfied: cftime==1.6.1 in /usr/local/lib/python3.7/dist-packages (from -r requirements.txt (line 35)) (1.6.1)
# Requirement already satisfied: chardet==3.0.4 in /usr/local/lib/python3.7/dist-packages (from -r requirements.txt (line 36)) (3.0.4)
# Requirement already satisfied: charset-normalizer==2.1.0 in /usr/local/lib/python3.7/dist-packages (from -r requirements.txt (line 37)) (2.1.0)
# Requirement already satisfied: click==7.1.2 in /usr/local/lib/python3.7/dist-packages (from -r requirements.txt (line 38)) (7.1.2)
# Requirement already satisfied: clikit==0.6.2 in /usr/local/lib/python3.7/dist-packages (from -r requirements.txt (line 39)) (0.6.2)
# Requirement already satisfied: cloudpickle==1.3.0 in /usr/local/lib/python3.7/dist-packages (from -r requirements.txt (line 40)) (1.3.0)
# Requirement already satisfied: cmake==3.22.6 in /usr/local/lib/python3.7/dist-packages (from -r requirements.txt (line 41)) (3.22.6)
# Requirement already satisfied: cmdstanpy==1.0.4 in /usr/local/lib/python3.7/dist-packages (from -r requirements.txt (line 42)) (1.0.4)
# Requirement already satisfied: colorcet==3.0.0 in /usr/local/lib/python3.7/dist-packages (from -r requirements.txt (line 43)) (3.0.0)
# Requirement already satisfied: colorlover==0.3.0 in /usr/local/lib/python3.7/dist-packages (from -r requirements.txt (line 44)) (0.3.0)
# Requirement already satisfied: community==1.0.0b1 in /usr/local/lib/python3.7/dist-packages (from -r requirements.txt (line 45)) (1.0.0b1)
# Requirement already satisfied: contextlib2==0.5.5 in /usr/local/lib/python3.7/dist-packages (from -r requirements.txt (line 46)) (0.5.5)
# Requirement already satisfied: conversational-sentence-encoder==0.0.5 in /usr/local/lib/python3.7/dist-packages (from -r requirements.txt (line 47)) (0.0.5)
# Requirement already satisfied: convertdate==2.4.0 in /usr/local/lib/python3.7/dist-packages (from -r requirements.txt (line 48)) (2.4.0)
# Requirement already satisfied: crashtest==0.3.1 in /usr/local/lib/python3.7/dist-packages (from -r requirements.txt (line 49)) (0.3.1)
# Requirement already satisfied: crcmod==1.7 in /usr/local/lib/python3.7/dist-packages (from -r requirements.txt (line 50)) (1.7)
# Requirement already satisfied: cufflinks==0.17.3 in /usr/local/lib/python3.7/dist-packages (from -r requirements.txt (line 51)) (0.17.3)
# Requirement already satisfied: cupy-cuda111==9.4.0 in /usr/local/lib/python3.7/dist-packages (from -r requirements.txt (line 52)) (9.4.0)
# Requirement already satisfied: cvxopt==1.3.0 in /usr/local/lib/python3.7/dist-packages (from -r requirements.txt (line 53)) (1.3.0)
# Requirement already satisfied: cvxpy==1.2.1 in /usr/local/lib/python3.7/dist-packages (from -r requirements.txt (line 54)) (1.2.1)
# Requirement already satisfied: cycler==0.11.0 in /usr/local/lib/python3.7/dist-packages (from -r requirements.txt (line 55)) (0.11.0)
# Requirement already satisfied: cymem==2.0.6 in /usr/local/lib/python3.7/dist-packages (from -r requirements.txt (line 56)) (2.0.6)
# Requirement already satisfied: Cython==0.29.32 in /usr/local/lib/python3.7/dist-packages (from -r requirements.txt (line 57)) (0.29.32)
# Requirement already satisfied: daft==0.0.4 in /usr/local/lib/python3.7/dist-packages (from -r requirements.txt (line 58)) (0.0.4)
# Requirement already satisfied: dask==2.12.0 in /usr/local/lib/python3.7/dist-packages (from -r requirements.txt (line 59)) (2.12.0)
# Requirement already satisfied: datascience==0.17.5 in /usr/local/lib/python3.7/dist-packages (from -r requirements.txt (line 60)) (0.17.5)
# Requirement already satisfied: debugpy==1.0.0 in /usr/local/lib/python3.7/dist-packages (from -r requirements.txt (line 61)) (1.0.0)
# Requirement already satisfied: decorator==4.4.2 in /usr/local/lib/python3.7/dist-packages (from -r requirements.txt (line 62)) (4.4.2)
# Requirement already satisfied: defusedxml==0.7.1 in /usr/local/lib/python3.7/dist-packages (from -r requirements.txt (line 63)) (0.7.1)
# Requirement already satisfied: deprecat==2.1.1 in /usr/local/lib/python3.7/dist-packages (from -r requirements.txt (line 64)) (2.1.1)
# Requirement already satisfied: descartes==1.1.0 in /usr/local/lib/python3.7/dist-packages (from -r requirements.txt (line 65)) (1.1.0)
# Requirement already satisfied: dill==0.3.5.1 in /usr/local/lib/python3.7/dist-packages (from -r requirements.txt (line 66)) (0.3.5.1)
# Requirement already satisfied: distributed==1.25.3 in /usr/local/lib/python3.7/dist-packages (from -r requirements.txt (line 67)) (1.25.3)
# Requirement already satisfied: dlib==19.24.0 in /usr/local/lib/python3.7/dist-packages (from -r requirements.txt (line 68)) (19.24.0)
# Requirement already satisfied: dm-tree==0.1.7 in /usr/local/lib/python3.7/dist-packages (from -r requirements.txt (line 69)) (0.1.7)
# Requirement already satisfied: docutils==0.17.1 in /usr/local/lib/python3.7/dist-packages (from -r requirements.txt (line 70)) (0.17.1)
# Requirement already satisfied: dopamine-rl==1.0.5 in /usr/local/lib/python3.7/dist-packages (from -r requirements.txt (line 71)) (1.0.5)
# Requirement already satisfied: earthengine-api==0.1.317 in /usr/local/lib/python3.7/dist-packages (from -r requirements.txt (line 72)) (0.1.317)
# Requirement already satisfied: easydict==1.9 in /usr/local/lib/python3.7/dist-packages (from -r requirements.txt (line 73)) (1.9)
# Requirement already satisfied: ecos==2.0.10 in /usr/local/lib/python3.7/dist-packages (from -r requirements.txt (line 74)) (2.0.10)
# Requirement already satisfied: editdistance==0.5.3 in /usr/local/lib/python3.7/dist-packages (from -r requirements.txt (line 75)) (0.5.3)
# Requirement already satisfied: emoji==2.0.0 in /usr/local/lib/python3.7/dist-packages (from -r requirements.txt (line 76)) (2.0.0)
# Requirement already satisfied: entrypoints==0.4 in /usr/local/lib/python3.7/dist-packages (from -r requirements.txt (line 78)) (0.4)
# Requirement already satisfied: ephem==4.1.3 in /usr/local/lib/python3.7/dist-packages (from -r requirements.txt (line 79)) (4.1.3)
# Requirement already satisfied: et-xmlfile==1.1.0 in /usr/local/lib/python3.7/dist-packages (from -r requirements.txt (line 80)) (1.1.0)
# Requirement already satisfied: etils==0.6.0 in /usr/local/lib/python3.7/dist-packages (from -r requirements.txt (line 81)) (0.6.0)
# Requirement already satisfied: fa2==0.3.5 in /usr/local/lib/python3.7/dist-packages (from -r requirements.txt (line 82)) (0.3.5)
# Requirement already satisfied: fastai==2.7.7 in /usr/local/lib/python3.7/dist-packages (from -r requirements.txt (line 83)) (2.7.7)
# Requirement already satisfied: fastcore==1.5.13 in /usr/local/lib/python3.7/dist-packages (from -r requirements.txt (line 84)) (1.5.13)
# Requirement already satisfied: fastdownload==0.0.7 in /usr/local/lib/python3.7/dist-packages (from -r requirements.txt (line 85)) (0.0.7)
# Requirement already satisfied: fastdtw==0.3.4 in /usr/local/lib/python3.7/dist-packages (from -r requirements.txt (line 86)) (0.3.4)
# Requirement already satisfied: fastjsonschema==2.16.1 in /usr/local/lib/python3.7/dist-packages (from -r requirements.txt (line 87)) (2.16.1)
# Requirement already satisfied: fastprogress==1.0.3 in /usr/local/lib/python3.7/dist-packages (from -r requirements.txt (line 88)) (1.0.3)
# Requirement already satisfied: fastrlock==0.8 in /usr/local/lib/python3.7/dist-packages (from -r requirements.txt (line 89)) (0.8)
# Requirement already satisfied: feather-format==0.4.1 in /usr/local/lib/python3.7/dist-packages (from -r requirements.txt (line 90)) (0.4.1)
# Requirement already satisfied: filelock==3.7.1 in /usr/local/lib/python3.7/dist-packages (from -r requirements.txt (line 91)) (3.7.1)
# Requirement already satisfied: firebase-admin==4.4.0 in /usr/local/lib/python3.7/dist-packages (from -r requirements.txt (line 92)) (4.4.0)
# Requirement already satisfied: fix-yahoo-finance==0.0.22 in /usr/local/lib/python3.7/dist-packages (from -r requirements.txt (line 93)) (0.0.22)
# Requirement already satisfied: Flask==1.1.4 in /usr/local/lib/python3.7/dist-packages (from -r requirements.txt (line 94)) (1.1.4)
# Requirement already satisfied: flatbuffers==2.0 in /usr/local/lib/python3.7/dist-packages (from -r requirements.txt (line 95)) (2.0)
# Requirement already satisfied: folium==0.12.1.post1 in /usr/local/lib/python3.7/dist-packages (from -r requirements.txt (line 96)) (0.12.1.post1)
# Requirement already satisfied: frozenlist==1.3.0 in /usr/local/lib/python3.7/dist-packages (from -r requirements.txt (line 97)) (1.3.0)
# Requirement already satisfied: future==0.16.0 in /usr/local/lib/python3.7/dist-packages (from -r requirements.txt (line 98)) (0.16.0)
# Requirement already satisfied: gast==0.5.3 in /usr/local/lib/python3.7/dist-packages (from -r requirements.txt (line 99)) (0.5.3)
# Requirement already satisfied: GDAL==2.2.2 in /usr/local/lib/python3.7/dist-packages (from -r requirements.txt (line 100)) (2.2.2)
# Requirement already satisfied: gdown==4.4.0 in /usr/local/lib/python3.7/dist-packages (from -r requirements.txt (line 101)) (4.4.0)
# Requirement already satisfied: gensim==3.6.0 in /usr/local/lib/python3.7/dist-packages (from -r requirements.txt (line 102)) (3.6.0)
# Requirement already satisfied: geographiclib==1.52 in /usr/local/lib/python3.7/dist-packages (from -r requirements.txt (line 103)) (1.52)
# Requirement already satisfied: geopy==1.17.0 in /usr/local/lib/python3.7/dist-packages (from -r requirements.txt (line 104)) (1.17.0)
# Requirement already satisfied: gin-config==0.5.0 in /usr/local/lib/python3.7/dist-packages (from -r requirements.txt (line 105)) (0.5.0)
# Requirement already satisfied: glob2==0.7 in /usr/local/lib/python3.7/dist-packages (from -r requirements.txt (line 106)) (0.7)
# Requirement already satisfied: graphviz==0.10.1 in /usr/local/lib/python3.7/dist-packages (from -r requirements.txt (line 107)) (0.10.1)
# Requirement already satisfied: greenlet==1.1.2 in /usr/local/lib/python3.7/dist-packages (from -r requirements.txt (line 108)) (1.1.2)
# Requirement already satisfied: grpcio==1.47.0 in /usr/local/lib/python3.7/dist-packages (from -r requirements.txt (line 109)) (1.47.0)
# Requirement already satisfied: gspread==3.4.2 in /usr/local/lib/python3.7/dist-packages (from -r requirements.txt (line 110)) (3.4.2)
# Requirement already satisfied: gspread-dataframe==3.0.8 in /usr/local/lib/python3.7/dist-packages (from -r requirements.txt (line 111)) (3.0.8)
# Requirement already satisfied: gym==0.21.0 in /usr/local/lib/python3.7/dist-packages (from -r requirements.txt (line 112)) (0.21.0)
# Requirement already satisfied: h5py==3.1.0 in /usr/local/lib/python3.7/dist-packages (from -r requirements.txt (line 113)) (3.1.0)
# Requirement already satisfied: HeapDict==1.0.1 in /usr/local/lib/python3.7/dist-packages (from -r requirements.txt (line 114)) (1.0.1)
# Requirement already satisfied: hijri-converter==2.2.4 in /usr/local/lib/python3.7/dist-packages (from -r requirements.txt (line 115)) (2.2.4)
# Requirement already satisfied: holidays==0.14.2 in /usr/local/lib/python3.7/dist-packages (from -r requirements.txt (line 116)) (0.14.2)
# Requirement already satisfied: holoviews==1.14.9 in /usr/local/lib/python3.7/dist-packages (from -r requirements.txt (line 117)) (1.14.9)
# Requirement already satisfied: html5lib==1.0.1 in /usr/local/lib/python3.7/dist-packages (from -r requirements.txt (line 118)) (1.0.1)
# Requirement already satisfied: httpimport==0.5.18 in /usr/local/lib/python3.7/dist-packages (from -r requirements.txt (line 119)) (0.5.18)
# Requirement already satisfied: httplib2==0.17.4 in /usr/local/lib/python3.7/dist-packages (from -r requirements.txt (line 120)) (0.17.4)
# Requirement already satisfied: httplib2shim==0.0.3 in /usr/local/lib/python3.7/dist-packages (from -r requirements.txt (line 121)) (0.0.3)
# Requirement already satisfied: httpstan==4.6.1 in /usr/local/lib/python3.7/dist-packages (from -r requirements.txt (line 122)) (4.6.1)
# Requirement already satisfied: huggingface-hub==0.8.1 in /usr/local/lib/python3.7/dist-packages (from -r requirements.txt (line 123)) (0.8.1)
# Requirement already satisfied: humanize==0.5.1 in /usr/local/lib/python3.7/dist-packages (from -r requirements.txt (line 124)) (0.5.1)
# Requirement already satisfied: hyperopt==0.1.2 in /usr/local/lib/python3.7/dist-packages (from -r requirements.txt (line 125)) (0.1.2)
# Requirement already satisfied: idna==2.10 in /usr/local/lib/python3.7/dist-packages (from -r requirements.txt (line 126)) (2.10)
# Requirement already satisfied: imageio==2.9.0 in /usr/local/lib/python3.7/dist-packages (from -r requirements.txt (line 127)) (2.9.0)
# Requirement already satisfied: imagesize==1.4.1 in /usr/local/lib/python3.7/dist-packages (from -r requirements.txt (line 128)) (1.4.1)
# Requirement already satisfied: imbalanced-learn==0.8.1 in /usr/local/lib/python3.7/dist-packages (from -r requirements.txt (line 129)) (0.8.1)
# Requirement already satisfied: imblearn==0.0 in /usr/local/lib/python3.7/dist-packages (from -r requirements.txt (line 130)) (0.0)
# Requirement already satisfied: imgaug==0.4.0 in /usr/local/lib/python3.7/dist-packages (from -r requirements.txt (line 131)) (0.4.0)
# Requirement already satisfied: importlib-metadata==4.12.0 in /usr/local/lib/python3.7/dist-packages (from -r requirements.txt (line 132)) (4.12.0)
# Requirement already satisfied: importlib-resources==5.9.0 in /usr/local/lib/python3.7/dist-packages (from -r requirements.txt (line 133)) (5.9.0)
# Requirement already satisfied: imutils==0.5.4 in /usr/local/lib/python3.7/dist-packages (from -r requirements.txt (line 134)) (0.5.4)
# Requirement already satisfied: inflect==2.1.0 in /usr/local/lib/python3.7/dist-packages (from -r requirements.txt (line 135)) (2.1.0)
# Requirement already satisfied: intel-openmp==2022.1.0 in /usr/local/lib/python3.7/dist-packages (from -r requirements.txt (line 136)) (2022.1.0)
# Requirement already satisfied: intervaltree==2.1.0 in /usr/local/lib/python3.7/dist-packages (from -r requirements.txt (line 137)) (2.1.0)
# Requirement already satisfied: ipykernel==4.10.1 in /usr/local/lib/python3.7/dist-packages (from -r requirements.txt (line 138)) (4.10.1)
# Requirement already satisfied: ipython==5.5.0 in /usr/local/lib/python3.7/dist-packages (from -r requirements.txt (line 139)) (5.5.0)
# Requirement already satisfied: ipython-genutils==0.2.0 in /usr/local/lib/python3.7/dist-packages (from -r requirements.txt (line 140)) (0.2.0)
# Requirement already satisfied: ipython-sql==0.3.9 in /usr/local/lib/python3.7/dist-packages (from -r requirements.txt (line 141)) (0.3.9)
# Requirement already satisfied: ipywidgets==7.7.1 in /usr/local/lib/python3.7/dist-packages (from -r requirements.txt (line 142)) (7.7.1)
# Requirement already satisfied: itsdangerous==1.1.0 in /usr/local/lib/python3.7/dist-packages (from -r requirements.txt (line 143)) (1.1.0)
# Requirement already satisfied: jax==0.3.14 in /usr/local/lib/python3.7/dist-packages (from -r requirements.txt (line 144)) (0.3.14)
# Requirement already satisfied: jedi==0.18.1 in /usr/local/lib/python3.7/dist-packages (from -r requirements.txt (line 146)) (0.18.1)
# Requirement already satisfied: jieba==0.42.1 in /usr/local/lib/python3.7/dist-packages (from -r requirements.txt (line 147)) (0.42.1)
# Requirement already satisfied: Jinja2==2.11.3 in /usr/local/lib/python3.7/dist-packages (from -r requirements.txt (line 148)) (2.11.3)
# Requirement already satisfied: joblib==1.1.0 in /usr/local/lib/python3.7/dist-packages (from -r requirements.txt (line 149)) (1.1.0)
# Requirement already satisfied: jpeg4py==0.1.4 in /usr/local/lib/python3.7/dist-packages (from -r requirements.txt (line 150)) (0.1.4)
# Requirement already satisfied: jsonschema==4.3.3 in /usr/local/lib/python3.7/dist-packages (from -r requirements.txt (line 151)) (4.3.3)
# Requirement already satisfied: jupyter==1.0.0 in /usr/local/lib/python3.7/dist-packages (from -r requirements.txt (line 152)) (1.0.0)
# Requirement already satisfied: jupyter-client==5.3.5 in /usr/local/lib/python3.7/dist-packages (from -r requirements.txt (line 153)) (5.3.5)
# Requirement already satisfied: jupyter-console==5.2.0 in /usr/local/lib/python3.7/dist-packages (from -r requirements.txt (line 154)) (5.2.0)
# Requirement already satisfied: jupyter-core==4.11.1 in /usr/local/lib/python3.7/dist-packages (from -r requirements.txt (line 155)) (4.11.1)
# Requirement already satisfied: jupyterlab-pygments==0.2.2 in /usr/local/lib/python3.7/dist-packages (from -r requirements.txt (line 156)) (0.2.2)
# Requirement already satisfied: jupyterlab-widgets==1.1.1 in /usr/local/lib/python3.7/dist-packages (from -r requirements.txt (line 157)) (1.1.1)
# Requirement already satisfied: kaggle==1.5.12 in /usr/local/lib/python3.7/dist-packages (from -r requirements.txt (line 158)) (1.5.12)
# Requirement already satisfied: kapre==0.3.7 in /usr/local/lib/python3.7/dist-packages (from -r requirements.txt (line 159)) (0.3.7)
# Requirement already satisfied: keras==2.8.0 in /usr/local/lib/python3.7/dist-packages (from -r requirements.txt (line 160)) (2.8.0)
# Requirement already satisfied: Keras-Applications==1.0.8 in /usr/local/lib/python3.7/dist-packages (from -r requirements.txt (line 161)) (1.0.8)
# Requirement already satisfied: Keras-Preprocessing==1.1.2 in /usr/local/lib/python3.7/dist-packages (from -r requirements.txt (line 162)) (1.1.2)
# Requirement already satisfied: keras-vis==0.4.1 in /usr/local/lib/python3.7/dist-packages (from -r requirements.txt (line 163)) (0.4.1)
# Requirement already satisfied: kiwisolver==1.4.4 in /usr/local/lib/python3.7/dist-packages (from -r requirements.txt (line 164)) (1.4.4)
# Requirement already satisfied: korean-lunar-calendar==0.2.1 in /usr/local/lib/python3.7/dist-packages (from -r requirements.txt (line 165)) (0.2.1)
# Requirement already satisfied: langcodes==3.3.0 in /usr/local/lib/python3.7/dist-packages (from -r requirements.txt (line 166)) (3.3.0)
# Requirement already satisfied: libclang==14.0.6 in /usr/local/lib/python3.7/dist-packages (from -r requirements.txt (line 167)) (14.0.6)
# Requirement already satisfied: librosa==0.8.1 in /usr/local/lib/python3.7/dist-packages (from -r requirements.txt (line 168)) (0.8.1)
# Requirement already satisfied: lightgbm==2.2.3 in /usr/local/lib/python3.7/dist-packages (from -r requirements.txt (line 169)) (2.2.3)
# Requirement already satisfied: llvmlite==0.39.0 in /usr/local/lib/python3.7/dist-packages (from -r requirements.txt (line 170)) (0.39.0)
# Requirement already satisfied: lmdb==0.99 in /usr/local/lib/python3.7/dist-packages (from -r requirements.txt (line 171)) (0.99)
# Requirement already satisfied: LunarCalendar==0.0.9 in /usr/local/lib/python3.7/dist-packages (from -r requirements.txt (line 172)) (0.0.9)
# Requirement already satisfied: lxml==4.9.1 in /usr/local/lib/python3.7/dist-packages (from -r requirements.txt (line 173)) (4.9.1)
# Requirement already satisfied: Markdown==3.4.1 in /usr/local/lib/python3.7/dist-packages (from -r requirements.txt (line 174)) (3.4.1)
# Requirement already satisfied: MarkupSafe==2.0.1 in /usr/local/lib/python3.7/dist-packages (from -r requirements.txt (line 175)) (2.0.1)
# Requirement already satisfied: marshmallow==3.17.0 in /usr/local/lib/python3.7/dist-packages (from -r requirements.txt (line 176)) (3.17.0)
# Requirement already satisfied: matplotlib==3.2.2 in /usr/local/lib/python3.7/dist-packages (from -r requirements.txt (line 177)) (3.2.2)
# Requirement already satisfied: matplotlib-inline==0.1.3 in /usr/local/lib/python3.7/dist-packages (from -r requirements.txt (line 178)) (0.1.3)
# Requirement already satisfied: matplotlib-venn==0.11.7 in /usr/local/lib/python3.7/dist-packages (from -r requirements.txt (line 179)) (0.11.7)
# Requirement already satisfied: missingno==0.5.1 in /usr/local/lib/python3.7/dist-packages (from -r requirements.txt (line 180)) (0.5.1)
# Requirement already satisfied: mistune==0.8.4 in /usr/local/lib/python3.7/dist-packages (from -r requirements.txt (line 181)) (0.8.4)
# Requirement already satisfied: mizani==0.6.0 in /usr/local/lib/python3.7/dist-packages (from -r requirements.txt (line 182)) (0.6.0)
# Requirement already satisfied: mkl==2019.0 in /usr/local/lib/python3.7/dist-packages (from -r requirements.txt (line 183)) (2019.0)
# Requirement already satisfied: mlxtend==0.14.0 in /usr/local/lib/python3.7/dist-packages (from -r requirements.txt (line 184)) (0.14.0)
# Requirement already satisfied: more-itertools==8.13.0 in /usr/local/lib/python3.7/dist-packages (from -r requirements.txt (line 185)) (8.13.0)
# Requirement already satisfied: moviepy==0.2.3.5 in /usr/local/lib/python3.7/dist-packages (from -r requirements.txt (line 186)) (0.2.3.5)
# Requirement already satisfied: mpmath==1.2.1 in /usr/local/lib/python3.7/dist-packages (from -r requirements.txt (line 187)) (1.2.1)
# Requirement already satisfied: msgpack==1.0.4 in /usr/local/lib/python3.7/dist-packages (from -r requirements.txt (line 188)) (1.0.4)
# Requirement already satisfied: multidict==6.0.2 in /usr/local/lib/python3.7/dist-packages (from -r requirements.txt (line 189)) (6.0.2)
# Requirement already satisfied: multitasking==0.0.11 in /usr/local/lib/python3.7/dist-packages (from -r requirements.txt (line 190)) (0.0.11)
# Requirement already satisfied: murmurhash==1.0.7 in /usr/local/lib/python3.7/dist-packages (from -r requirements.txt (line 191)) (1.0.7)
# Requirement already satisfied: music21==5.5.0 in /usr/local/lib/python3.7/dist-packages (from -r requirements.txt (line 192)) (5.5.0)
# Requirement already satisfied: natsort==5.5.0 in /usr/local/lib/python3.7/dist-packages (from -r requirements.txt (line 193)) (5.5.0)
# Requirement already satisfied: nbclient==0.6.6 in /usr/local/lib/python3.7/dist-packages (from -r requirements.txt (line 194)) (0.6.6)
# Requirement already satisfied: nbconvert==5.6.1 in /usr/local/lib/python3.7/dist-packages (from -r requirements.txt (line 195)) (5.6.1)
# Requirement already satisfied: nbformat==5.4.0 in /usr/local/lib/python3.7/dist-packages (from -r requirements.txt (line 196)) (5.4.0)
# Requirement already satisfied: nest-asyncio==1.5.5 in /usr/local/lib/python3.7/dist-packages (from -r requirements.txt (line 197)) (1.5.5)
# Requirement already satisfied: netCDF4==1.6.0 in /usr/local/lib/python3.7/dist-packages (from -r requirements.txt (line 198)) (1.6.0)
# Requirement already satisfied: networkx==2.6.3 in /usr/local/lib/python3.7/dist-packages (from -r requirements.txt (line 199)) (2.6.3)
# Requirement already satisfied: nibabel==3.0.2 in /usr/local/lib/python3.7/dist-packages (from -r requirements.txt (line 200)) (3.0.2)
# Requirement already satisfied: nltk==3.7 in /usr/local/lib/python3.7/dist-packages (from -r requirements.txt (line 201)) (3.7)
# Requirement already satisfied: notebook==5.3.1 in /usr/local/lib/python3.7/dist-packages (from -r requirements.txt (line 202)) (5.3.1)
# Requirement already satisfied: numba==0.56.0 in /usr/local/lib/python3.7/dist-packages (from -r requirements.txt (line 203)) (0.56.0)
# Requirement already satisfied: numexpr==2.8.3 in /usr/local/lib/python3.7/dist-packages (from -r requirements.txt (line 204)) (2.8.3)
# Requirement already satisfied: numpy==1.21.0 in /usr/local/lib/python3.7/dist-packages (from -r requirements.txt (line 205)) (1.21.0)
# Requirement already satisfied: oauth2client==4.1.3 in /usr/local/lib/python3.7/dist-packages (from -r requirements.txt (line 206)) (4.1.3)
# Requirement already satisfied: oauthlib==3.2.0 in /usr/local/lib/python3.7/dist-packages (from -r requirements.txt (line 207)) (3.2.0)
# Requirement already satisfied: okgrade==0.4.3 in /usr/local/lib/python3.7/dist-packages (from -r requirements.txt (line 208)) (0.4.3)
# Requirement already satisfied: opencv-contrib-python==4.6.0.66 in /usr/local/lib/python3.7/dist-packages (from -r requirements.txt (line 209)) (4.6.0.66)
# Requirement already satisfied: opencv-python==4.6.0.66 in /usr/local/lib/python3.7/dist-packages (from -r requirements.txt (line 210)) (4.6.0.66)
# Requirement already satisfied: opencv-python-headless==4.6.0.66 in /usr/local/lib/python3.7/dist-packages (from -r requirements.txt (line 211)) (4.6.0.66)
# Requirement already satisfied: openpyxl==3.0.10 in /usr/local/lib/python3.7/dist-packages (from -r requirements.txt (line 212)) (3.0.10)
# Requirement already satisfied: opt-einsum==3.3.0 in /usr/local/lib/python3.7/dist-packages (from -r requirements.txt (line 213)) (3.3.0)
# Requirement already satisfied: osqp==0.6.2.post0 in /usr/local/lib/python3.7/dist-packages (from -r requirements.txt (line 214)) (0.6.2.post0)
# Requirement already satisfied: packaging==21.3 in /usr/local/lib/python3.7/dist-packages (from -r requirements.txt (line 215)) (21.3)
# Requirement already satisfied: palettable==3.3.0 in /usr/local/lib/python3.7/dist-packages (from -r requirements.txt (line 216)) (3.3.0)
# Requirement already satisfied: pandas==1.3.5 in /usr/local/lib/python3.7/dist-packages (from -r requirements.txt (line 217)) (1.3.5)
# Requirement already satisfied: pandas-datareader==0.9.0 in /usr/local/lib/python3.7/dist-packages (from -r requirements.txt (line 218)) (0.9.0)
# Requirement already satisfied: pandas-gbq==0.13.3 in /usr/local/lib/python3.7/dist-packages (from -r requirements.txt (line 219)) (0.13.3)
# Requirement already satisfied: pandas-profiling==1.4.1 in /usr/local/lib/python3.7/dist-packages (from -r requirements.txt (line 220)) (1.4.1)
# Requirement already satisfied: pandocfilters==1.5.0 in /usr/local/lib/python3.7/dist-packages (from -r requirements.txt (line 221)) (1.5.0)
# Requirement already satisfied: panel==0.12.1 in /usr/local/lib/python3.7/dist-packages (from -r requirements.txt (line 222)) (0.12.1)
# Requirement already satisfied: param==1.12.2 in /usr/local/lib/python3.7/dist-packages (from -r requirements.txt (line 223)) (1.12.2)
# Requirement already satisfied: parso==0.8.3 in /usr/local/lib/python3.7/dist-packages (from -r requirements.txt (line 224)) (0.8.3)
# Requirement already satisfied: pastel==0.2.1 in /usr/local/lib/python3.7/dist-packages (from -r requirements.txt (line 225)) (0.2.1)
# Requirement already satisfied: pathlib==1.0.1 in /usr/local/lib/python3.7/dist-packages (from -r requirements.txt (line 226)) (1.0.1)
# Requirement already satisfied: pathy==0.6.2 in /usr/local/lib/python3.7/dist-packages (from -r requirements.txt (line 227)) (0.6.2)
# Requirement already satisfied: patsy==0.5.2 in /usr/local/lib/python3.7/dist-packages (from -r requirements.txt (line 228)) (0.5.2)
# Requirement already satisfied: pep517==0.13.0 in /usr/local/lib/python3.7/dist-packages (from -r requirements.txt (line 229)) (0.13.0)
# Requirement already satisfied: pexpect==4.8.0 in /usr/local/lib/python3.7/dist-packages (from -r requirements.txt (line 230)) (4.8.0)
# Requirement already satisfied: pickleshare==0.7.5 in /usr/local/lib/python3.7/dist-packages (from -r requirements.txt (line 231)) (0.7.5)
# Requirement already satisfied: Pillow==7.1.2 in /usr/local/lib/python3.7/dist-packages (from -r requirements.txt (line 232)) (7.1.2)
# Requirement already satisfied: pip-tools==6.2.0 in /usr/local/lib/python3.7/dist-packages (from -r requirements.txt (line 233)) (6.2.0)
# Requirement already satisfied: pkgutil-resolve-name==1.3.10 in /usr/local/lib/python3.7/dist-packages (from -r requirements.txt (line 234)) (1.3.10)
# Requirement already satisfied: plotly==5.5.0 in /usr/local/lib/python3.7/dist-packages (from -r requirements.txt (line 235)) (5.5.0)
# Requirement already satisfied: plotnine==0.6.0 in /usr/local/lib/python3.7/dist-packages (from -r requirements.txt (line 236)) (0.6.0)
# Requirement already satisfied: pluggy==0.7.1 in /usr/local/lib/python3.7/dist-packages (from -r requirements.txt (line 237)) (0.7.1)
# Requirement already satisfied: pooch==1.6.0 in /usr/local/lib/python3.7/dist-packages (from -r requirements.txt (line 238)) (1.6.0)
# Requirement already satisfied: portpicker==1.3.9 in /usr/local/lib/python3.7/dist-packages (from -r requirements.txt (line 239)) (1.3.9)
# Requirement already satisfied: prefetch-generator==1.0.1 in /usr/local/lib/python3.7/dist-packages (from -r requirements.txt (line 240)) (1.0.1)
# Requirement already satisfied: preshed==3.0.6 in /usr/local/lib/python3.7/dist-packages (from -r requirements.txt (line 241)) (3.0.6)
# Requirement already satisfied: prettytable==3.3.0 in /usr/local/lib/python3.7/dist-packages (from -r requirements.txt (line 242)) (3.3.0)
# Requirement already satisfied: progressbar2==3.38.0 in /usr/local/lib/python3.7/dist-packages (from -r requirements.txt (line 243)) (3.38.0)
# Requirement already satisfied: prometheus-client==0.14.1 in /usr/local/lib/python3.7/dist-packages (from -r requirements.txt (line 244)) (0.14.1)
# Requirement already satisfied: promise==2.3 in /usr/local/lib/python3.7/dist-packages (from -r requirements.txt (line 245)) (2.3)
# Requirement already satisfied: prompt-toolkit==1.0.18 in /usr/local/lib/python3.7/dist-packages (from -r requirements.txt (line 246)) (1.0.18)
# Requirement already satisfied: prophet==1.1 in /usr/local/lib/python3.7/dist-packages (from -r requirements.txt (line 247)) (1.1)
# Requirement already satisfied: protobuf==3.17.3 in /usr/local/lib/python3.7/dist-packages (from -r requirements.txt (line 248)) (3.17.3)
# Requirement already satisfied: psutil==5.4.8 in /usr/local/lib/python3.7/dist-packages (from -r requirements.txt (line 249)) (5.4.8)
# Requirement already satisfied: psycopg2==2.9.3 in /usr/local/lib/python3.7/dist-packages (from -r requirements.txt (line 250)) (2.9.3)
# Requirement already satisfied: ptyprocess==0.7.0 in /usr/local/lib/python3.7/dist-packages (from -r requirements.txt (line 251)) (0.7.0)
# Requirement already satisfied: py==1.11.0 in /usr/local/lib/python3.7/dist-packages (from -r requirements.txt (line 252)) (1.11.0)
# Requirement already satisfied: pyarrow==6.0.1 in /usr/local/lib/python3.7/dist-packages (from -r requirements.txt (line 253)) (6.0.1)
# Requirement already satisfied: pyasn1==0.4.8 in /usr/local/lib/python3.7/dist-packages (from -r requirements.txt (line 254)) (0.4.8)
# Requirement already satisfied: pyasn1-modules==0.2.8 in /usr/local/lib/python3.7/dist-packages (from -r requirements.txt (line 255)) (0.2.8)
# Requirement already satisfied: pycocotools==2.0.4 in /usr/local/lib/python3.7/dist-packages (from -r requirements.txt (line 256)) (2.0.4)
# Requirement already satisfied: pycparser==2.21 in /usr/local/lib/python3.7/dist-packages (from -r requirements.txt (line 257)) (2.21)
# Requirement already satisfied: pyct==0.4.8 in /usr/local/lib/python3.7/dist-packages (from -r requirements.txt (line 258)) (0.4.8)
# Requirement already satisfied: pydantic==1.9.1 in /usr/local/lib/python3.7/dist-packages (from -r requirements.txt (line 259)) (1.9.1)
# Requirement already satisfied: pydata-google-auth==1.4.0 in /usr/local/lib/python3.7/dist-packages (from -r requirements.txt (line 260)) (1.4.0)
# Requirement already satisfied: pydot==1.3.0 in /usr/local/lib/python3.7/dist-packages (from -r requirements.txt (line 261)) (1.3.0)
# Requirement already satisfied: pydot-ng==2.0.0 in /usr/local/lib/python3.7/dist-packages (from -r requirements.txt (line 262)) (2.0.0)
# Requirement already satisfied: pydotplus==2.0.2 in /usr/local/lib/python3.7/dist-packages (from -r requirements.txt (line 263)) (2.0.2)
# Requirement already satisfied: PyDrive==1.3.1 in /usr/local/lib/python3.7/dist-packages (from -r requirements.txt (line 264)) (1.3.1)
# Requirement already satisfied: pyemd==0.5.1 in /usr/local/lib/python3.7/dist-packages (from -r requirements.txt (line 265)) (0.5.1)
# Requirement already satisfied: pyerfa==2.0.0.1 in /usr/local/lib/python3.7/dist-packages (from -r requirements.txt (line 266)) (2.0.0.1)
# Requirement already satisfied: pyglet==1.5.0 in /usr/local/lib/python3.7/dist-packages (from -r requirements.txt (line 267)) (1.5.0)
# Requirement already satisfied: Pygments==2.6.1 in /usr/local/lib/python3.7/dist-packages (from -r requirements.txt (line 268)) (2.6.1)
# Requirement already satisfied: pygobject==3.26.1 in /usr/lib/python3/dist-packages (from -r requirements.txt (line 269)) (3.26.1)
# Requirement already satisfied: pylev==1.4.0 in /usr/local/lib/python3.7/dist-packages (from -r requirements.txt (line 270)) (1.4.0)
# Requirement already satisfied: pymc3==3.11.5 in /usr/local/lib/python3.7/dist-packages (from -r requirements.txt (line 271)) (3.11.5)
# Requirement already satisfied: PyMeeus==0.5.11 in /usr/local/lib/python3.7/dist-packages (from -r requirements.txt (line 272)) (0.5.11)
# Requirement already satisfied: pymongo==4.2.0 in /usr/local/lib/python3.7/dist-packages (from -r requirements.txt (line 273)) (4.2.0)
# Requirement already satisfied: pymystem3==0.2.0 in /usr/local/lib/python3.7/dist-packages (from -r requirements.txt (line 274)) (0.2.0)
# Requirement already satisfied: PyOpenGL==3.1.6 in /usr/local/lib/python3.7/dist-packages (from -r requirements.txt (line 275)) (3.1.6)
# Requirement already satisfied: pyparsing==3.0.9 in /usr/local/lib/python3.7/dist-packages (from -r requirements.txt (line 276)) (3.0.9)
# Requirement already satisfied: pyrsistent==0.18.1 in /usr/local/lib/python3.7/dist-packages (from -r requirements.txt (line 277)) (0.18.1)
# Requirement already satisfied: pysimdjson==3.2.0 in /usr/local/lib/python3.7/dist-packages (from -r requirements.txt (line 278)) (3.2.0)
# Requirement already satisfied: pysndfile==1.3.8 in /usr/local/lib/python3.7/dist-packages (from -r requirements.txt (line 279)) (1.3.8)
# Requirement already satisfied: PySocks==1.7.1 in /usr/local/lib/python3.7/dist-packages (from -r requirements.txt (line 280)) (1.7.1)
# Requirement already satisfied: pystan==3.3.0 in /usr/local/lib/python3.7/dist-packages (from -r requirements.txt (line 281)) (3.3.0)
# Requirement already satisfied: pytest==3.6.4 in /usr/local/lib/python3.7/dist-packages (from -r requirements.txt (line 282)) (3.6.4)
# Requirement already satisfied: python-apt==0.0.0 in /usr/local/lib/python3.7/dist-packages (from -r requirements.txt (line 283)) (0.0.0)
# Requirement already satisfied: python-chess==0.23.11 in /usr/local/lib/python3.7/dist-packages (from -r requirements.txt (line 284)) (0.23.11)
# Requirement already satisfied: python-dateutil==2.8.2 in /usr/local/lib/python3.7/dist-packages (from -r requirements.txt (line 285)) (2.8.2)
# Requirement already satisfied: python-louvain==0.16 in /usr/local/lib/python3.7/dist-packages (from -r requirements.txt (line 286)) (0.16)
# Requirement already satisfied: python-slugify==6.1.2 in /usr/local/lib/python3.7/dist-packages (from -r requirements.txt (line 287)) (6.1.2)
# Requirement already satisfied: python-utils==3.3.3 in /usr/local/lib/python3.7/dist-packages (from -r requirements.txt (line 288)) (3.3.3)
# Requirement already satisfied: pytz==2022.1 in /usr/local/lib/python3.7/dist-packages (from -r requirements.txt (line 289)) (2022.1)
# Requirement already satisfied: pyviz-comms==2.2.0 in /usr/local/lib/python3.7/dist-packages (from -r requirements.txt (line 290)) (2.2.0)
# Requirement already satisfied: PyWavelets==1.3.0 in /usr/local/lib/python3.7/dist-packages (from -r requirements.txt (line 291)) (1.3.0)
# Requirement already satisfied: PyYAML==6.0 in /usr/local/lib/python3.7/dist-packages (from -r requirements.txt (line 292)) (6.0)
# Requirement already satisfied: pyzmq==23.2.0 in /usr/local/lib/python3.7/dist-packages (from -r requirements.txt (line 293)) (23.2.0)
# Requirement already satisfied: qdldl==0.1.5.post2 in /usr/local/lib/python3.7/dist-packages (from -r requirements.txt (line 294)) (0.1.5.post2)
# Requirement already satisfied: qtconsole==5.3.1 in /usr/local/lib/python3.7/dist-packages (from -r requirements.txt (line 295)) (5.3.1)
# Requirement already satisfied: QtPy==2.1.0 in /usr/local/lib/python3.7/dist-packages (from -r requirements.txt (line 296)) (2.1.0)
# Requirement already satisfied: qudida==0.0.4 in /usr/local/lib/python3.7/dist-packages (from -r requirements.txt (line 297)) (0.0.4)
# Requirement already satisfied: regex==2022.6.2 in /usr/local/lib/python3.7/dist-packages (from -r requirements.txt (line 298)) (2022.6.2)
# Requirement already satisfied: requests==2.23.0 in /usr/local/lib/python3.7/dist-packages (from -r requirements.txt (line 299)) (2.23.0)
# Requirement already satisfied: requests-oauthlib==1.3.1 in /usr/local/lib/python3.7/dist-packages (from -r requirements.txt (line 300)) (1.3.1)
# Requirement already satisfied: resampy==0.3.1 in /usr/local/lib/python3.7/dist-packages (from -r requirements.txt (line 301)) (0.3.1)
# Requirement already satisfied: rpy2==3.4.5 in /usr/local/lib/python3.7/dist-packages (from -r requirements.txt (line 302)) (3.4.5)
# Requirement already satisfied: rsa==4.9 in /usr/local/lib/python3.7/dist-packages (from -r requirements.txt (line 303)) (4.9)
# Requirement already satisfied: scikit-image==0.18.3 in /usr/local/lib/python3.7/dist-packages (from -r requirements.txt (line 304)) (0.18.3)
# Requirement already satisfied: scikit-learn==1.0.2 in /usr/local/lib/python3.7/dist-packages (from -r requirements.txt (line 305)) (1.0.2)
# Requirement already satisfied: scipy==1.7.3 in /usr/local/lib/python3.7/dist-packages (from -r requirements.txt (line 306)) (1.7.3)
# Requirement already satisfied: screen-resolution-extra==0.0.0 in /usr/lib/python3/dist-packages (from -r requirements.txt (line 307)) (0.0.0)
# Requirement already satisfied: scs==3.2.0 in /usr/local/lib/python3.7/dist-packages (from -r requirements.txt (line 308)) (3.2.0)
# Requirement already satisfied: seaborn==0.11.2 in /usr/local/lib/python3.7/dist-packages (from -r requirements.txt (line 309)) (0.11.2)
# Requirement already satisfied: semver==2.13.0 in /usr/local/lib/python3.7/dist-packages (from -r requirements.txt (line 310)) (2.13.0)
# Requirement already satisfied: Send2Trash==1.8.0 in /usr/local/lib/python3.7/dist-packages (from -r requirements.txt (line 311)) (1.8.0)
# Requirement already satisfied: setuptools-git==1.2 in /usr/local/lib/python3.7/dist-packages (from -r requirements.txt (line 312)) (1.2)
# Requirement already satisfied: Shapely==1.8.2 in /usr/local/lib/python3.7/dist-packages (from -r requirements.txt (line 313)) (1.8.2)
# Requirement already satisfied: simplegeneric==0.8.1 in /usr/local/lib/python3.7/dist-packages (from -r requirements.txt (line 314)) (0.8.1)
# Requirement already satisfied: six==1.15.0 in /usr/local/lib/python3.7/dist-packages (from -r requirements.txt (line 315)) (1.15.0)
# Requirement already satisfied: sklearn==0.0 in /usr/local/lib/python3.7/dist-packages (from -r requirements.txt (line 316)) (0.0)
# Requirement already satisfied: sklearn-pandas==1.8.0 in /usr/local/lib/python3.7/dist-packages (from -r requirements.txt (line 317)) (1.8.0)
# Requirement already satisfied: smart-open==5.2.1 in /usr/local/lib/python3.7/dist-packages (from -r requirements.txt (line 318)) (5.2.1)
# Requirement already satisfied: snowballstemmer==2.2.0 in /usr/local/lib/python3.7/dist-packages (from -r requirements.txt (line 319)) (2.2.0)
# Requirement already satisfied: sortedcontainers==2.4.0 in /usr/local/lib/python3.7/dist-packages (from -r requirements.txt (line 320)) (2.4.0)
# Requirement already satisfied: SoundFile==0.10.3.post1 in /usr/local/lib/python3.7/dist-packages (from -r requirements.txt (line 321)) (0.10.3.post1)
# Requirement already satisfied: soupsieve==2.3.2.post1 in /usr/local/lib/python3.7/dist-packages (from -r requirements.txt (line 322)) (2.3.2.post1)
# Requirement already satisfied: spacy==3.4.1 in /usr/local/lib/python3.7/dist-packages (from -r requirements.txt (line 323)) (3.4.1)
# Requirement already satisfied: spacy-legacy==3.0.9 in /usr/local/lib/python3.7/dist-packages (from -r requirements.txt (line 324)) (3.0.9)
# Requirement already satisfied: spacy-loggers==1.0.3 in /usr/local/lib/python3.7/dist-packages (from -r requirements.txt (line 325)) (1.0.3)
# Requirement already satisfied: Sphinx==1.8.6 in /usr/local/lib/python3.7/dist-packages (from -r requirements.txt (line 326)) (1.8.6)
# Requirement already satisfied: sphinxcontrib-serializinghtml==1.1.5 in /usr/local/lib/python3.7/dist-packages (from -r requirements.txt (line 327)) (1.1.5)
# Requirement already satisfied: sphinxcontrib-websupport==1.2.4 in /usr/local/lib/python3.7/dist-packages (from -r requirements.txt (line 328)) (1.2.4)
# Requirement already satisfied: SQLAlchemy==1.4.39 in /usr/local/lib/python3.7/dist-packages (from -r requirements.txt (line 329)) (1.4.39)
# Requirement already satisfied: sqlparse==0.4.2 in /usr/local/lib/python3.7/dist-packages (from -r requirements.txt (line 330)) (0.4.2)
# Requirement already satisfied: srsly==2.4.4 in /usr/local/lib/python3.7/dist-packages (from -r requirements.txt (line 331)) (2.4.4)
# Requirement already satisfied: stable-baselines3==1.6.0 in /usr/local/lib/python3.7/dist-packages (from -r requirements.txt (line 332)) (1.6.0)
# Requirement already satisfied: statsmodels==0.10.2 in /usr/local/lib/python3.7/dist-packages (from -r requirements.txt (line 333)) (0.10.2)
# Requirement already satisfied: sympy==1.7.1 in /usr/local/lib/python3.7/dist-packages (from -r requirements.txt (line 334)) (1.7.1)
# Requirement already satisfied: tables==3.7.0 in /usr/local/lib/python3.7/dist-packages (from -r requirements.txt (line 335)) (3.7.0)
# Requirement already satisfied: tabulate==0.8.10 in /usr/local/lib/python3.7/dist-packages (from -r requirements.txt (line 336)) (0.8.10)
# Requirement already satisfied: tblib==1.7.0 in /usr/local/lib/python3.7/dist-packages (from -r requirements.txt (line 337)) (1.7.0)
# Requirement already satisfied: tenacity==8.0.1 in /usr/local/lib/python3.7/dist-packages (from -r requirements.txt (line 338)) (8.0.1)
# Requirement already satisfied: tensorboard==2.0.0 in /usr/local/lib/python3.7/dist-packages (from -r requirements.txt (line 339)) (2.0.0)
# Requirement already satisfied: tensorboard-data-server==0.6.1 in /usr/local/lib/python3.7/dist-packages (from -r requirements.txt (line 340)) (0.6.1)
# Requirement already satisfied: tensorboard-plugin-wit==1.8.1 in /usr/local/lib/python3.7/dist-packages (from -r requirements.txt (line 341)) (1.8.1)
# Requirement already satisfied: tensorflow==1.14.0 in /usr/local/lib/python3.7/dist-packages (from -r requirements.txt (line 342)) (1.14.0)
# Requirement already satisfied: tensorflow-datasets==4.6.0 in /usr/local/lib/python3.7/dist-packages (from -r requirements.txt (line 343)) (4.6.0)
# Requirement already satisfied: tensorflow-estimator==1.14.0 in /usr/local/lib/python3.7/dist-packages (from -r requirements.txt (line 344)) (1.14.0)
# Requirement already satisfied: tensorflow-gcs-config==2.8.0 in /usr/local/lib/python3.7/dist-packages (from -r requirements.txt (line 345)) (2.8.0)
# Requirement already satisfied: tensorflow-hub==0.6.0 in /usr/local/lib/python3.7/dist-packages (from -r requirements.txt (line 346)) (0.6.0)
# Requirement already satisfied: tensorflow-io-gcs-filesystem==0.26.0 in /usr/local/lib/python3.7/dist-packages (from -r requirements.txt (line 347)) (0.26.0)
# Requirement already satisfied: tensorflow-metadata==1.9.0 in /usr/local/lib/python3.7/dist-packages (from -r requirements.txt (line 348)) (1.9.0)
# Requirement already satisfied: tensorflow-probability==0.16.0 in /usr/local/lib/python3.7/dist-packages (from -r requirements.txt (line 349)) (0.16.0)
# Requirement already satisfied: tensorflow-text==0.1.0 in /usr/local/lib/python3.7/dist-packages (from -r requirements.txt (line 350)) (0.1.0)
# Requirement already satisfied: termcolor==1.1.0 in /usr/local/lib/python3.7/dist-packages (from -r requirements.txt (line 351)) (1.1.0)
# Requirement already satisfied: terminado==0.13.3 in /usr/local/lib/python3.7/dist-packages (from -r requirements.txt (line 352)) (0.13.3)
# Requirement already satisfied: testpath==0.6.0 in /usr/local/lib/python3.7/dist-packages (from -r requirements.txt (line 353)) (0.6.0)
# Requirement already satisfied: text-unidecode==1.3 in /usr/local/lib/python3.7/dist-packages (from -r requirements.txt (line 354)) (1.3)
# Requirement already satisfied: textblob==0.15.3 in /usr/local/lib/python3.7/dist-packages (from -r requirements.txt (line 355)) (0.15.3)
# Requirement already satisfied: tf-sentencepiece==0.1.83 in /usr/local/lib/python3.7/dist-packages (from -r requirements.txt (line 356)) (0.1.83)
# Requirement already satisfied: Theano-PyMC==1.1.2 in /usr/local/lib/python3.7/dist-packages (from -r requirements.txt (line 357)) (1.1.2)
# Requirement already satisfied: thinc==8.1.0 in /usr/local/lib/python3.7/dist-packages (from -r requirements.txt (line 358)) (8.1.0)
# Requirement already satisfied: threadpoolctl==3.1.0 in /usr/local/lib/python3.7/dist-packages (from -r requirements.txt (line 359)) (3.1.0)
# Requirement already satisfied: tifffile==2021.11.2 in /usr/local/lib/python3.7/dist-packages (from -r requirements.txt (line 360)) (2021.11.2)
# Requirement already satisfied: tinycss2==1.1.1 in /usr/local/lib/python3.7/dist-packages (from -r requirements.txt (line 361)) (1.1.1)
# Requirement already satisfied: tokenizers==0.12.1 in /usr/local/lib/python3.7/dist-packages (from -r requirements.txt (line 362)) (0.12.1)
# Requirement already satisfied: toml==0.10.2 in /usr/local/lib/python3.7/dist-packages (from -r requirements.txt (line 363)) (0.10.2)
# Requirement already satisfied: tomli==2.0.1 in /usr/local/lib/python3.7/dist-packages (from -r requirements.txt (line 364)) (2.0.1)
# Requirement already satisfied: toolz==0.12.0 in /usr/local/lib/python3.7/dist-packages (from -r requirements.txt (line 365)) (0.12.0)
# Requirement already satisfied: torchsummary==1.5.1 in /usr/local/lib/python3.7/dist-packages (from -r requirements.txt (line 368)) (1.5.1)
# Requirement already satisfied: torchtext==0.13.0 in /usr/local/lib/python3.7/dist-packages (from -r requirements.txt (line 369)) (0.13.0)
# Requirement already satisfied: tornado==5.1.1 in /usr/local/lib/python3.7/dist-packages (from -r requirements.txt (line 371)) (5.1.1)
# Requirement already satisfied: tqdm==4.64.0 in /usr/local/lib/python3.7/dist-packages (from -r requirements.txt (line 372)) (4.64.0)
# Requirement already satisfied: traitlets==5.1.1 in /usr/local/lib/python3.7/dist-packages (from -r requirements.txt (line 373)) (5.1.1)
# Requirement already satisfied: transformers==4.19.2 in /usr/local/lib/python3.7/dist-packages (from -r requirements.txt (line 374)) (4.19.2)
# Requirement already satisfied: tweepy==3.10.0 in /usr/local/lib/python3.7/dist-packages (from -r requirements.txt (line 375)) (3.10.0)
# Requirement already satisfied: typeguard==2.7.1 in /usr/local/lib/python3.7/dist-packages (from -r requirements.txt (line 376)) (2.7.1)
# Requirement already satisfied: typer==0.4.2 in /usr/local/lib/python3.7/dist-packages (from -r requirements.txt (line 377)) (0.4.2)
# Requirement already satisfied: typing-extensions==4.1.1 in /usr/local/lib/python3.7/dist-packages (from -r requirements.txt (line 378)) (4.1.1)
# Requirement already satisfied: tzlocal==1.5.1 in /usr/local/lib/python3.7/dist-packages (from -r requirements.txt (line 379)) (1.5.1)
# Requirement already satisfied: ujson==5.4.0 in /usr/local/lib/python3.7/dist-packages (from -r requirements.txt (line 380)) (5.4.0)
# Requirement already satisfied: uritemplate==3.0.1 in /usr/local/lib/python3.7/dist-packages (from -r requirements.txt (line 381)) (3.0.1)
# Collecting urllib3==1.24.3
#   Using cached urllib3-1.24.3-py2.py3-none-any.whl (118 kB)
# Requirement already satisfied: vega-datasets==0.9.0 in /usr/local/lib/python3.7/dist-packages (from -r requirements.txt (line 383)) (0.9.0)
# Requirement already satisfied: wasabi==0.10.1 in /usr/local/lib/python3.7/dist-packages (from -r requirements.txt (line 384)) (0.10.1)
# Requirement already satisfied: wcwidth==0.2.5 in /usr/local/lib/python3.7/dist-packages (from -r requirements.txt (line 385)) (0.2.5)
# Requirement already satisfied: webargs==8.2.0 in /usr/local/lib/python3.7/dist-packages (from -r requirements.txt (line 386)) (8.2.0)
# Requirement already satisfied: webencodings==0.5.1 in /usr/local/lib/python3.7/dist-packages (from -r requirements.txt (line 387)) (0.5.1)
# Requirement already satisfied: Werkzeug==1.0.1 in /usr/local/lib/python3.7/dist-packages (from -r requirements.txt (line 388)) (1.0.1)
# Requirement already satisfied: widgetsnbextension==3.6.1 in /usr/local/lib/python3.7/dist-packages (from -r requirements.txt (line 389)) (3.6.1)
# Requirement already satisfied: wordcloud==1.8.2.2 in /usr/local/lib/python3.7/dist-packages (from -r requirements.txt (line 390)) (1.8.2.2)
# Requirement already satisfied: wrapt==1.14.1 in /usr/local/lib/python3.7/dist-packages (from -r requirements.txt (line 391)) (1.14.1)
# Requirement already satisfied: xarray==0.20.2 in /usr/local/lib/python3.7/dist-packages (from -r requirements.txt (line 392)) (0.20.2)
# Requirement already satisfied: xarray-einstats==0.2.2 in /usr/local/lib/python3.7/dist-packages (from -r requirements.txt (line 393)) (0.2.2)
# Requirement already satisfied: xgboost==0.90 in /usr/local/lib/python3.7/dist-packages (from -r requirements.txt (line 394)) (0.90)
# Requirement already satisfied: xkit==0.0.0 in /usr/lib/python3/dist-packages (from -r requirements.txt (line 395)) (0.0.0)
# Requirement already satisfied: xlrd==1.1.0 in /usr/local/lib/python3.7/dist-packages (from -r requirements.txt (line 396)) (1.1.0)
# Requirement already satisfied: xlwt==1.3.0 in /usr/local/lib/python3.7/dist-packages (from -r requirements.txt (line 397)) (1.3.0)
# Requirement already satisfied: yarl==1.8.1 in /usr/local/lib/python3.7/dist-packages (from -r requirements.txt (line 398)) (1.8.1)
# Requirement already satisfied: yellowbrick==1.4 in /usr/local/lib/python3.7/dist-packages (from -r requirements.txt (line 399)) (1.4)
# Requirement already satisfied: zict==2.2.0 in /usr/local/lib/python3.7/dist-packages (from -r requirements.txt (line 400)) (2.2.0)
# Requirement already satisfied: zipp==3.8.1 in /usr/local/lib/python3.7/dist-packages (from -r requirements.txt (line 401)) (3.8.1)
# Installing collected packages: urllib3
#   Attempting uninstall: urllib3
#     Found existing installation: urllib3 1.25.11
#     Uninstalling urllib3-1.25.11:
#       Successfully uninstalled urllib3-1.25.11
# Successfully installed urllib3-1.24.3

# %%
# !python -m spacy download en_core_web_sm
# Out:
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/framework/dtypes.py:516: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint8 = np.dtype([("qint8", np.int8, 1)])
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/framework/dtypes.py:517: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint8 = np.dtype([("quint8", np.uint8, 1)])
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/framework/dtypes.py:518: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint16 = np.dtype([("qint16", np.int16, 1)])
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/framework/dtypes.py:519: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint16 = np.dtype([("quint16", np.uint16, 1)])
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/framework/dtypes.py:520: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint32 = np.dtype([("qint32", np.int32, 1)])
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/framework/dtypes.py:525: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   np_resource = np.dtype([("resource", np.ubyte, 1)])
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting en-core-web-sm==3.4.0
#   Using cached https://github.com/explosion/spacy-models/releases/download/en_core_web_sm-3.4.0/en_core_web_sm-3.4.0-py3-none-any.whl (12.8 MB)
# Requirement already satisfied: spacy<3.5.0,>=3.4.0 in /usr/local/lib/python3.7/dist-packages (from en-core-web-sm==3.4.0) (3.4.1)
# Requirement already satisfied: tqdm<5.0.0,>=4.38.0 in /usr/local/lib/python3.7/dist-packages (from spacy<3.5.0,>=3.4.0->en-core-web-sm==3.4.0) (4.64.0)
# Requirement already satisfied: preshed<3.1.0,>=3.0.2 in /usr/local/lib/python3.7/dist-packages (from spacy<3.5.0,>=3.4.0->en-core-web-sm==3.4.0) (3.0.6)
# Requirement already satisfied: spacy-legacy<3.1.0,>=3.0.9 in /usr/local/lib/python3.7/dist-packages (from spacy<3.5.0,>=3.4.0->en-core-web-sm==3.4.0) (3.0.9)
# Requirement already satisfied: murmurhash<1.1.0,>=0.28.0 in /usr/local/lib/python3.7/dist-packages (from spacy<3.5.0,>=3.4.0->en-core-web-sm==3.4.0) (1.0.7)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.7/dist-packages (from spacy<3.5.0,>=3.4.0->en-core-web-sm==3.4.0) (21.3)
# Requirement already satisfied: catalogue<2.1.0,>=2.0.6 in /usr/local/lib/python3.7/dist-packages (from spacy<3.5.0,>=3.4.0->en-core-web-sm==3.4.0) (2.0.8)
# Requirement already satisfied: numpy>=1.15.0 in /usr/local/lib/python3.7/dist-packages (from spacy<3.5.0,>=3.4.0->en-core-web-sm==3.4.0) (1.21.0)
# Requirement already satisfied: pydantic!=1.8,!=1.8.1,<1.10.0,>=1.7.4 in /usr/local/lib/python3.7/dist-packages (from spacy<3.5.0,>=3.4.0->en-core-web-sm==3.4.0) (1.9.1)
# Requirement already satisfied: cymem<2.1.0,>=2.0.2 in /usr/local/lib/python3.7/dist-packages (from spacy<3.5.0,>=3.4.0->en-core-web-sm==3.4.0) (2.0.6)
# Requirement already satisfied: thinc<8.2.0,>=8.1.0 in /usr/local/lib/python3.7/dist-packages (from spacy<3.5.0,>=3.4.0->en-core-web-sm==3.4.0) (8.1.0)
# Requirement already satisfied: wasabi<1.1.0,>=0.9.1 in /usr/local/lib/python3.7/dist-packages (from spacy<3.5.0,>=3.4.0->en-core-web-sm==3.4.0) (0.10.1)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.7/dist-packages (from spacy<3.5.0,>=3.4.0->en-core-web-sm==3.4.0) (2.11.3)
# Requirement already satisfied: pathy>=0.3.5 in /usr/local/lib/python3.7/dist-packages (from spacy<3.5.0,>=3.4.0->en-core-web-sm==3.4.0) (0.6.2)
# Requirement already satisfied: typer<0.5.0,>=0.3.0 in /usr/local/lib/python3.7/dist-packages (from spacy<3.5.0,>=3.4.0->en-core-web-sm==3.4.0) (0.4.2)
# Requirement already satisfied: langcodes<4.0.0,>=3.2.0 in /usr/local/lib/python3.7/dist-packages (from spacy<3.5.0,>=3.4.0->en-core-web-sm==3.4.0) (3.3.0)
# Requirement already satisfied: requests<3.0.0,>=2.13.0 in /usr/local/lib/python3.7/dist-packages (from spacy<3.5.0,>=3.4.0->en-core-web-sm==3.4.0) (2.23.0)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.7/dist-packages (from spacy<3.5.0,>=3.4.0->en-core-web-sm==3.4.0) (57.4.0)
# Requirement already satisfied: typing-extensions<4.2.0,>=3.7.4 in /usr/local/lib/python3.7/dist-packages (from spacy<3.5.0,>=3.4.0->en-core-web-sm==3.4.0) (4.1.1)
# Requirement already satisfied: srsly<3.0.0,>=2.4.3 in /usr/local/lib/python3.7/dist-packages (from spacy<3.5.0,>=3.4.0->en-core-web-sm==3.4.0) (2.4.4)
# Requirement already satisfied: spacy-loggers<2.0.0,>=1.0.0 in /usr/local/lib/python3.7/dist-packages (from spacy<3.5.0,>=3.4.0->en-core-web-sm==3.4.0) (1.0.3)
# Requirement already satisfied: zipp>=0.5 in /usr/local/lib/python3.7/dist-packages (from catalogue<2.1.0,>=2.0.6->spacy<3.5.0,>=3.4.0->en-core-web-sm==3.4.0) (3.8.1)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in /usr/local/lib/python3.7/dist-packages (from packaging>=20.0->spacy<3.5.0,>=3.4.0->en-core-web-sm==3.4.0) (3.0.9)
# Requirement already satisfied: smart-open<6.0.0,>=5.2.1 in /usr/local/lib/python3.7/dist-packages (from pathy>=0.3.5->spacy<3.5.0,>=3.4.0->en-core-web-sm==3.4.0) (5.2.1)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.7/dist-packages (from requests<3.0.0,>=2.13.0->spacy<3.5.0,>=3.4.0->en-core-web-sm==3.4.0) (1.24.3)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.7/dist-packages (from requests<3.0.0,>=2.13.0->spacy<3.5.0,>=3.4.0->en-core-web-sm==3.4.0) (2.10)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.7/dist-packages (from requests<3.0.0,>=2.13.0->spacy<3.5.0,>=3.4.0->en-core-web-sm==3.4.0) (2022.6.15)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.7/dist-packages (from requests<3.0.0,>=2.13.0->spacy<3.5.0,>=3.4.0->en-core-web-sm==3.4.0) (3.0.4)
# Requirement already satisfied: blis<0.8.0,>=0.7.8 in /usr/local/lib/python3.7/dist-packages (from thinc<8.2.0,>=8.1.0->spacy<3.5.0,>=3.4.0->en-core-web-sm==3.4.0) (0.7.8)
# Requirement already satisfied: click<9.0.0,>=7.1.1 in /usr/local/lib/python3.7/dist-packages (from typer<0.5.0,>=0.3.0->spacy<3.5.0,>=3.4.0->en-core-web-sm==3.4.0) (7.1.2)
# Requirement already satisfied: MarkupSafe>=0.23 in /usr/local/lib/python3.7/dist-packages (from jinja2->spacy<3.5.0,>=3.4.0->en-core-web-sm==3.4.0) (2.0.1)
# ✔ Download and installation successful
# You can now load the package via spacy.load('en_core_web_sm')

# %%
# Code from RLinfer_single
# cut from environment.py and RLmain, which is adapted from https://github.com/vwxyzjn/cleanrl/
# which references https://github.com/pranz24/pytorch-soft-actor-critic and https://github.com/openai/spinningup
# also referencing https://github.com/pranz24/pytorch-soft-actor-critic
import argparse
import os
from distutils.util import strtobool
import random
import sys
import time
import numpy as np
import torch
import gym
o_path = os.getcwd()
sys.path.append(o_path)
from dyme_reward import environment
from rl import model as rlmodel
from stable_baselines3.common.buffers import ReplayBuffer
from torch.utils.tensorboard import SummaryWriter
import warnings
from conversational_sentence_encoder.vectorizers import SentenceEncoder
from transformers import AutoTokenizer, AutoModelForSeq2SeqLM
from seq2seq_models import conversation as tconversation

parser = argparse.ArgumentParser()

#parser.add_argument("--exp-name", type=str, default=os.path.basename(__file__).rstrip(".py"),
#	help="the name of this experiment")
parser.add_argument("--seed", type=int, default=1,
	help="seed of the experiment")
parser.add_argument("--env-id", type=str, default="Chatbot",
	help="the id of the environment")
parser.add_argument("--torch-deterministic", type=lambda x: bool(strtobool(x)), default=True, nargs="?", const=True,
	help="if toggled, `torch.backends.cudnn.deterministic=False`")
parser.add_argument("--cuda", type=lambda x: bool(strtobool(x)), default=True, nargs="?", const=True,
	help="if toggled, cuda will be enabled by default")
parser.add_argument("--prompting", type=lambda x:bool(strtobool(x)), default=True, nargs="?", const=True,
	help="enable prompting")
parser.add_argument("--inferring", type=lambda x:bool(strtobool(x)), default=True, nargs="?", const=True,
	help="enable inferring")
args, unknown = parser.parse_known_args()

def input2output(uinput, sys_conv, encoder):
  chat_history = []
  chat_history.append(uinput)
  dialogue_encoded = encoder.encode_multicontext(chat_history)
  embedding = np.arctan(0.1 * dialogue_encoded) * 2 / np.pi
  obs = embedding.reshape(-1)
  action, _, _ = agent.get_action(torch.Tensor(obs).to(device), training=False)  # Sample action from policy
  action = action.detach().cpu().numpy()
  uinput = ' '.join(chat_history)
  prompt = behaviourandquestion(action)
  output = sys_conv.add_user_input(uinput, **prompt)
  return output

def behaviourandquestion(action):
    qu = action[1]
    be = action[0]
    prompt = dict()
    if qu > 0: #question
        prompt['qst'] = 'ask me for further details. '
        #behaviours
    if be < -1:
        prompt['bhv'] = "I'm in a negative mood, please comfort me."
    elif be >= -1 and be < 0:
        prompt['bhv'] = "give me some advice."
    elif be >= 1 and be < 2:
        prompt['bhv'] = "I'm in a positive mood, please congratulate me and praise me."
    return prompt

warnings.filterwarnings("ignore")
save_model_path_colab = o_path+'/savedmodels'
#run_name = f"infer:{args.env_id}__{args.exp_name}__{args.seed}__{int(time.time())}"
#writer = SummaryWriter(f"runs/{run_name}")
#writer.add_text(
#	"hyperparameters",
#	"|param|value|\n|-|-|\n%s" % ("\n".join([f"|{key}|{value}|" for key, value in vars(args).items()])),
#)
seed = args.seed
random.seed(seed)
np.random.seed(seed)
torch.manual_seed(seed)
torch.backends.cudnn.deterministic = args.torch_deterministic		

device = torch.device("cuda" if torch.cuda.is_available() and args.cuda else "cpu")

tokenizer = AutoTokenizer.from_pretrained("Adapting/dialogue_agent_nlplab2022")
model = AutoModelForSeq2SeqLM.from_pretrained("Adapting/dialogue_agent_nlplab2022", revision = 'b86f62986872b4c1a9921acdb8cd226761d736cf')
sys_conv = tconversation.Conversation(model, tokenizer, 128, device)
multicontext_encoder = SentenceEncoder(multiple_contexts=True)
# Agent
actsp = gym.spaces.Box(np.array([-2,-1]), np.array([+2,+1])) 
obsp = gym.spaces.Box(np.array([-1]*512), np.array([1]*512))
actsp.seed(seed)
obsp.seed(seed)
agent = rlmodel.Actor(obsp, actsp)

if os.path.exists(save_model_path_colab+'/savedmodel'+".t7"):
    save_path = save_model_path_colab+'/savedmodel'+".t7"
    checkpoint = torch.load(save_path)
    agent.load_state_dict(checkpoint['actor'])
    start_global_step = checkpoint['global_step']
    print("records: ", start_global_step)
    start_global_step += 1
else:
		print("Alarm. No existing model.")
agent = agent.to(device)
agent.eval()
# Out:
# records:  4100
# Actor(
#   (fc1): Linear(in_features=512, out_features=256, bias=True)
#   (fc2): Linear(in_features=256, out_features=256, bias=True)
#   (fc_mean): Linear(in_features=256, out_features=2, bias=True)
#   (fc_logstd): Linear(in_features=256, out_features=2, bias=True)
# )

# %%
# Tao: generating response with RLPA and save
for i in range(len(test_dataset)):
    chat_history = test_dataset.loc[i,'chat_history']
    # remove prompts
    index = chat_history.index('[qst]')
    chat_history = chat_history[:index-1]
    print(chat_history)
    #feed chat_history to RLPA
    response = input2output(chat_history, sys_conv)
    print(response)
    print("line:", i)
    test_dataset.loc[i,'RLPA_response'] = response
    test_dataset.to_csv('generated_responses.csv')

# %%
# modified: generating response with RLPA and save
import csv
lines = len(test_dataset)
#lines = 100
fieldnames = ['Unnamed: 0','id','chat_history','sys_response','situation','emotion','question or not','behavior','RLPA_response']
with open('generated_responses.csv','r+',encoding='UTF8', newline='') as csvfile:
    reader = csv.reader(csvfile)
    ended_at = len(list(reader))-1
for i in range(ended_at, lines):
    print("line:", i)
    chat_history = test_dataset.loc[i,'chat_history']
    # remove prompts
    index = chat_history.index('[qst]')
    chat_history = chat_history[:index-1]
    print(chat_history)

    #feed chat_history to RLPA
    response = input2output(chat_history, sys_conv, multicontext_encoder)
    print(response)
    #test_dataset.loc[i,'RLPA_response'] = response
    with open('generated_responses.csv','a',encoding='UTF8', newline='') as csvfile:
      writer = csv.DictWriter(csvfile,fieldnames)
      tobe_written = [{'Unnamed: 0':test_dataset.loc[i,"Unnamed: 0"],'id':test_dataset.loc[i,"id"],'chat_history':test_dataset.loc[i,"chat_history"],'sys_response':test_dataset.loc[i,"sys_response"],'emotion':test_dataset.loc[i,"emotion"],'question or not':test_dataset.loc[i,"question or not"],'behavior':test_dataset.loc[i,"behavior"],'RLPA_response':response}]
      writer.writerows(tobe_written)
    test_dataset.to_csv('generated_responses.csv')
# Out:
# line: 133
# [usr] I came home, and my wife showed me a picture in 4d of our future baby, my heart speeded so fast! [sys] oh wow. Do you know whether it will be a boy or girl yet? [usr] We choose to wait! but the amount of happiness in my body is tremendous! never felt this way before.
# Token indices sequence length is longer than the specified maximum sequence length for this model (138 > 128). Running this sequence through the model will result in indexing errors
# Do you have a name picked out yet or are you just going to let the magic happen?
# line: 134
# [usr] I love being in the flow -- whether it's in speaking to a group of people or working to help facilitate meetings.
# Me too, I love the feeling of being talked to by someone who knows what they are talking about.
# line: 135
# [usr] I love being in the flow -- whether it's in speaking to a group of people or working to help facilitate meetings. [sys] What kind of work do you do? [usr] I work with different organizations on strengthening their culture, and I do large-scale visual notetaking (also known as graphic recording). Are you familiar with that at all? (Not unusual NOT to be!)
# No I'm not but it sounds very interesting! I do a lot of work for my community.
# line: 136
# [usr] I LOVE when leaders know that it actually *helps* them to be surrounded by strong people -- people they can learn from, that challenge them, and that in some ways could be considered better.
# I absolutely agree with you! It makes the job so much better when you have a strong leader!
# line: 137
# [usr] I LOVE when leaders know that it actually *helps* them to be surrounded by strong people -- people they can learn from, that challenge them, and that in some ways could be considered better. [sys] I agree, its always nice to have people around you who are smarter in some areas [usr] It's just too many leaders want yes men and/or people who feel non-threatening. It's a trap and a quick path to mediocrity, if not failure!
# Its a trap for sure, but its a good thing that they are trying to get people to want to do better
# line: 138
# [usr] I'll always remember the day I learned I was pregnant with our first child -- Halloween in Chicago, and we were with friends at the Shedd Aquarium! I've loved baby belugas since ;-)
# Oh that must have been so exciting! Babies are so much fun. I'm glad you loved it so much!
# line: 139
# [usr] I'll always remember the day I learned I was pregnant with our first child -- Halloween in Chicago, and we were with friends at the Shedd Aquarium! I've loved baby belugas since ;-) [sys] Baby belugas are cute, but not as cute as your baby! [usr] Ha! True that ;-) That's also the year that A Bug's Life came out, and we always thought of our young one as Dot, the spunky little girl ant in the movie.
# That's awesome. I'm sure you will have many more memories like that with your kiddo. How old is she now?
# line: 140
# [usr] This mother's day was amazing! I got so much more than expected and it was all so heartfelt
# Mother's day is my favorite day of the year, I am so glad you had a good one!
# line: 141
# [usr] This mother's day was amazing! I got so much more than expected and it was all so heartfelt [sys] That is great!!  Sometimes we mom's get a bit forgotten, so to have an entire day where we are just loved is such a great feeling. [usr] Yes, definitely! I actually cried a few times because of how much thought went into each gift and what was written in the cards
